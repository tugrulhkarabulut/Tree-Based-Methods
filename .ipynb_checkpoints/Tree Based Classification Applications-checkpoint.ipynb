# %%
import numpy as np
import pandas as pd
from time import time
from sklearn import tree

from DecisionTreeClassifier import DecisionTreeClassifier

# %%
def train_test_split(X, ratio=0.8):
    X_shuffled = np.copy(X)
    np.random.shuffle(X_shuffled)
    return X_shuffled[:int(len(X_shuffled) * ratio)], X_shuffled[int(len(X_shuffled) * ratio):]

# %%
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# px_width           -0.008402 -0.041533    -0.009476  0.014291 -0.005176
# ram                -0.000653  0.026351     0.003443  0.041072  0.015099
# sc_h               -0.029959 -0.002952    -0.029078 -0.011949 -0.011014
# sc_w               -0.021421  0.000613    -0.007378 -0.016666 -0.012373
# talk_time           0.052510  0.013934    -0.011432 -0.039404 -0.006829
# three_g             0.011522 -0.030236    -0.046433 -0.014008  0.001793
# touch_screen       -0.010516  0.010061     0.019756 -0.017117 -0.014828
# wifi               -0.008343 -0.021863    -0.024471  0.022740  0.020085
# price_range         0.200723  0.020573    -0.006606  0.017444  0.021998
#
#                  four_g  int_memory     m_dep  mobile_wt   n_cores  ...  \
# battery_power  0.015665   -0.004004  0.034085   0.001844 -0.029727  ...
# blue           0.013443    0.041177  0.004049  -0.008605  0.036161  ...
# clock_speed   -0.043073    0.006545 -0.014364   0.012350 -0.005724  ...
# dual_sim       0.003187   -0.015679 -0.022142  -0.008979 -0.024658  ...
# fc            -0.016560   -0.029133 -0.001791   0.023618 -0.013356  ...
# four_g         1.000000    0.008690 -0.001823  -0.016537 -0.029706  ...
# int_memory     0.008690    1.000000  0.006886  -0.034214 -0.028310  ...
# m_dep         -0.001823    0.006886  1.000000   0.021756 -0.003504  ...
# mobile_wt     -0.016537   -0.034214  0.021756   1.000000 -0.018989  ...
# n_cores       -0.029706   -0.028310 -0.003504  -0.018989  1.000000  ...
# pc            -0.005598   -0.033273  0.026282   0.018844 -0.001193  ...
# px_height     -0.019236    0.010441  0.025263   0.000939 -0.006872  ...
# px_width       0.007448   -0.008335  0.023566   0.000090  0.024480  ...
# ram            0.007313    0.032813 -0.009434  -0.002581  0.004868  ...
# sc_h           0.027166    0.037771 -0.025348  -0.033855 -0.000315  ...
# sc_w           0.037005    0.011731 -0.018388  -0.020761  0.025826  ...
# talk_time     -0.046628   -0.002790  0.017003   0.006209  0.013148  ...
# three_g        0.584246   -0.009366 -0.012065   0.001551 -0.014733  ...
# touch_screen   0.016758   -0.026999 -0.002638  -0.014368  0.023774  ...
# wifi          -0.017620    0.006993 -0.028353  -0.000409 -0.009964  ...
# price_range    0.014772    0.044435  0.000853  -0.030302  0.004399  ...
#
#                px_height  px_width       ram      sc_h      sc_w  talk_time  \
# battery_power   0.014901 -0.008402 -0.000653 -0.029959 -0.021421   0.052510
# blue           -0.006872 -0.041533  0.026351 -0.002952  0.000613   0.013934
# clock_speed    -0.014523 -0.009476  0.003443 -0.029078 -0.007378  -0.011432
# dual_sim       -0.020875  0.014291  0.041072 -0.011949 -0.016666  -0.039404
# fc             -0.009990 -0.005176  0.015099 -0.011014 -0.012373  -0.006829
# four_g         -0.019236  0.007448  0.007313  0.027166  0.037005  -0.046628
# int_memory      0.010441 -0.008335  0.032813  0.037771  0.011731  -0.002790
# m_dep           0.025263  0.023566 -0.009434 -0.025348 -0.018388   0.017003
# mobile_wt       0.000939  0.000090 -0.002581 -0.033855 -0.020761   0.006209
# n_cores        -0.006872  0.024480  0.004868 -0.000315  0.025826   0.013148
# pc             -0.018465  0.004196  0.028984  0.004938 -0.023819   0.014657
# px_height       1.000000  0.510664 -0.020352  0.059615  0.043038  -0.010645
# px_width        0.510664  1.000000  0.004105  0.021599  0.034699   0.006720
# ram            -0.020352  0.004105  1.000000  0.015996  0.035576   0.010820
# sc_h            0.059615  0.021599  0.015996  1.000000  0.506144  -0.017335
# sc_w            0.043038  0.034699  0.035576  0.506144  1.000000  -0.022821
# talk_time      -0.010645  0.006720  0.010820 -0.017335 -0.022821   1.000000
# three_g        -0.031174  0.000350  0.015795  0.012033  0.030941  -0.042688
# touch_screen    0.021891 -0.001628 -0.030455 -0.020023  0.012720   0.017196
# wifi            0.051824  0.030319  0.022669  0.025929  0.035423  -0.029504
# price_range     0.148858  0.165818  0.917046  0.022986  0.038711   0.021859
#
#                 three_g  touch_screen      wifi  price_range
# battery_power  0.011522     -0.010516 -0.008343     0.200723
# blue          -0.030236      0.010061 -0.021863     0.020573
# clock_speed   -0.046433      0.019756 -0.024471    -0.006606
# dual_sim      -0.014008     -0.017117  0.022740     0.017444
# fc             0.001793     -0.014828  0.020085     0.021998
# four_g         0.584246      0.016758 -0.017620     0.014772
# int_memory    -0.009366     -0.026999  0.006993     0.044435
# m_dep         -0.012065     -0.002638 -0.028353     0.000853
# mobile_wt      0.001551     -0.014368 -0.000409    -0.030302
# n_cores       -0.014733      0.023774 -0.009964     0.004399
# pc            -0.001322     -0.008742  0.005389     0.033599
# px_height     -0.031174      0.021891  0.051824     0.148858
# px_width       0.000350     -0.001628  0.030319     0.165818
# ram            0.015795     -0.030455  0.022669     0.917046
# sc_h           0.012033     -0.020023  0.025929     0.022986
# sc_w           0.030941      0.012720  0.035423     0.038711
# talk_time     -0.042688      0.017196 -0.029504     0.021859
# three_g        1.000000      0.013917  0.004316     0.023611
# touch_screen   0.013917      1.000000  0.011917    -0.030411
# wifi           0.004316      0.011917  1.000000     0.018785
# price_range    0.023611     -0.030411  0.018785     1.000000
#
# [21 rows x 21 columns]

# %%
df['ram_below_mean'] = (df['ram'] < df['ram'].mean()) * 1

# %%
df['battery_power_below_mean'] = (df['battery_power'] < df['battery_power'].mean()) * 1

# %%
df['ram_below_75'] = (df['ram'] < df['ram'].quantile(0.75)) * 1

# %%
for feature in ['ram_below_mean', 'battery_power_below_mean', 'ram_below_75']:
    df[feature] = df[feature].astype('category')
    #df_test[feature] = df_test[feature].astype('category')

# %%
model = DecisionTreeClassifier()

# %%
X = df[['ram', 'battery_power']]
y = df['price_range']

# %%
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-332-6d10fe8973eb> in <module>
# ----> 1 model.fit(X, y)
#
# ~/Documents/python/ai-research-lab/algorithms/Tree-Based-Classification-Implementations/DecisionTreeClassifier.py in fit(self, X, y)
#      67     def fit(self, X, y):
#      68         self.tree_ = Node()
# ---> 69         self.__generate_tree(self.tree_, self.__get_values(X), self.__get_values(y))
#      70
#      71     def __generate_tree(self, tree, X, y):
#
# ~/Documents/python/ai-research-lab/algorithms/Tree-Based-Classification-Implementations/DecisionTreeClassifier.py in __generate_tree(self, tree, X, y)
#      92             tree.children.append(new_node)
#      93             new_node.parent = tree
# ---> 94             self.__generate_tree(new_node, X[branch_indices], y[branch_indices])
#      95
#      96
#
# ~/Documents/python/ai-research-lab/algorithms/Tree-Based-Classification-Implementations/DecisionTreeClassifier.py in __generate_tree(self, tree, X, y)
#      92             tree.children.append(new_node)
#      93             new_node.parent = tree
# ---> 94             self.__generate_tree(new_node, X[branch_indices], y[branch_indices])
#      95
#      96
#
# ~/Documents/python/ai-research-lab/algorithms/Tree-Based-Classification-Implementations/DecisionTreeClassifier.py in __generate_tree(self, tree, X, y)
#      71     def __generate_tree(self, tree, X, y):
#      72         if len(y) <= self.min_members or tree.calc_entropy(y, store=True) < self.tol:
# ---> 73             self.__label_node(tree, y)
#      74             return
#      75
#
# ~/Documents/python/ai-research-lab/algorithms/Tree-Based-Classification-Implementations/DecisionTreeClassifier.py in __label_node(self, node, y)
#     134
#     135     def __label_node(self, node, y):
# --> 136         most_frequent = np.mode(y)
#     137         rand = np.random.randint(len(most_frequent))
#     138         node.leaf = True
#
# /usr/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     217                 return Tester
#     218             else:
# --> 219                 raise AttributeError("module {!r} has no attribute "
#     220                                      "{!r}".format(__name__, attr))
#     221
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
model.score(X, y)
# Out:
# 0.8275

# %%
model1 = tree.DecisionTreeClassifier(min_samples_leaf=2)

# %%
df = pd.read_csv('weatherAUS.csv')

# %%
df.dropna(inplace=True)

# %%
df.iloc[:, 9:]
# Out:
#        WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 5939          ENE         SW           6.0          20.0         20.0
# 5940          SSE        SSE          19.0          19.0         30.0
# 5942          NNE        NNW          30.0          15.0         42.0
# 5943          WNW        WSW           6.0           6.0         37.0
# 5944           NW        WNW          17.0          13.0         19.0
# ...           ...        ...           ...           ...          ...
# 139108         SE         NE           9.0          20.0         63.0
# 139109         SE         SE          13.0          11.0         56.0
# 139110          E          W          17.0          11.0         46.0
# 139111         SE        NNW           9.0          17.0         62.0
# 139112        ENE        NNW          15.0           7.0         73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 5939           13.0       1006.3       1004.4       2.0       5.0     26.6
# 5940            8.0       1012.9       1012.1       1.0       1.0     20.3
# 5942           22.0       1012.3       1009.2       1.0       6.0     28.7
# 5943           22.0       1012.7       1009.1       1.0       5.0     29.1
# 5944           15.0       1010.7       1007.4       1.0       6.0     33.6
# ...             ...          ...          ...       ...       ...      ...
# 139108         32.0       1013.9       1010.5       0.0       1.0     24.5
# 139109         28.0       1014.6       1011.2       7.0       0.0     24.8
# 139110         23.0       1015.3       1011.8       0.0       0.0     24.8
# 139111         58.0       1014.9       1010.7       1.0       1.0     24.8
# 139112         32.0       1013.9       1009.7       6.0       5.0     25.4
#
#         Temp3pm RainToday  RISK_MM RainTomorrow
# 5939       33.4        No      0.0           No
# 5940       27.0        No      0.0           No
# 5942       34.9        No      0.0           No
# 5943       35.6        No      0.0           No
# 5944       37.6        No      0.0           No
# ...         ...       ...      ...          ...
# 139108     32.3        No      0.0           No
# 139109     32.0        No      0.0           No
# 139110     32.1        No      0.0           No
# 139111     29.2        No      0.0           No
# 139112     31.0        No      0.0           No
#
# [56420 rows x 15 columns]

# %%
model = DecisionTreeClassifier(min_members=20)

# %%
for feature in ['Location', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'RainToday']:
    df[feature] = df[feature].astype('category')
    df[feature] = df[feature].cat.codes

# %%
X = df[['Location', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'RainToday', 'Temp3pm']]
y = df['RainTomorrow']

# %%
a=time()
model.fit(X, y)
b=time()

b-a
# Out:
# 27.67387342453003

# %%
y_pred = model.predict(X)

# %%
y_pred[y==y_pred].size / y.size
# Out:
# 0.7880716058135413

# %%
model_s = tree.DecisionTreeClassifier(min_samples_leaf=20)

# %%
a=time()
model_s.fit(X, y)
b=time()

b-a
# Out:
# 0.1601123809814453

# %%
model_s.score(X, y)
# Out:
# 0.8345267635590217

# %%
np.issubdtype(x[:, 0].dtype, np.object)
# Out:
# <ipython-input-239-d4cb82c40c08>:1: FutureWarning: Conversion of the second argument of issubdtype from `object` to `np.generic` is deprecated. In future, it will be treated as `np.object_ == np.dtype(object).type`.
#   np.issubdtype(x[:, 0].dtype, np.object)
# True

# %%
np.issubdtype(x[:, 0].dtype, np.number)
# Out:
# True

# %%
df.values[:, 0].astype('int')
# Out:
# array([ 842, 1021,  563, ..., 1911, 1512,  510])

# %%
a = df.values[:, 0]

# %%
b = np.array(['a', 'b', 'c'])

# %%
b.astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-283-116e1e1c20dd> in <module>
# ----> 1 b.astype('int')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
type(y.values)
# Out:
# numpy.ndarray

# %%
type(np.unique(y.values))
# Out:
# numpy.ndarray

# %%
np.where(a < 900)
# Out:
# (array([   0,    2,    3,    9,   10,   13,   15,   16,   17,   19,   20,
#           24,   26,   29,   34,   35,   36,   38,   39,   48,   49,   56,
#           61,   64,   65,   72,   74,   75,   88,   92,   93,   98,   99,
#          102,  104,  105,  110,  111,  112,  121,  122,  126,  132,  133,
#          137,  138,  139,  143,  149,  150,  151,  156,  165,  166,  172,
#          174,  176,  179,  180,  190,  194,  198,  203,  205,  208,  220,
#          221,  234,  240,  241,  242,  246,  250,  252,  253,  256,  257,
#          258,  260,  261,  263,  271,  274,  278,  279,  283,  286,  289,
#          294,  302,  312,  313,  318,  320,  330,  335,  336,  337,  340,
#          341,  344,  345,  346,  347,  348,  349,  350,  354,  357,  360,
#          361,  363,  365,  366,  367,  375,  383,  384,  387,  396,  397,
#          407,  414,  415,  417,  424,  434,  436,  438,  450,  458,  459,
#          468,  470,  477,  490,  492,  499,  507,  508,  510,  524,  526,
#          531,  532,  536,  537,  538,  539,  540,  541,  542,  544,  545,
#          548,  552,  558,  564,  576,  585,  586,  590,  594,  595,  597,
#          613,  614,  615,  618,  619,  623,  625,  635,  636,  640,  641,
#          646,  649,  653,  654,  660,  666,  667,  669,  670,  671,  673,
#          675,  679,  680,  682,  684,  687,  689,  692,  695,  700,  702,
#          710,  715,  716,  721,  724,  726,  733,  735,  736,  737,  745,
#          748,  749,  756,  757,  761,  762,  765,  769,  771,  772,  776,
#          778,  779,  786,  803,  810,  811,  813,  816,  822,  829,  830,
#          837,  838,  841,  848,  850,  851,  852,  854,  859,  861,  865,
#          871,  872,  873,  884,  885,  886,  901,  903,  909,  912,  914,
#          916,  922,  931,  934,  936,  937,  938,  941,  944,  945,  951,
#          953,  956,  964,  973,  974,  975,  989,  991,  993,  994,  996,
#         1000, 1002, 1010, 1011, 1012, 1016, 1026, 1027, 1036, 1039, 1045,
#         1047, 1049, 1050, 1051, 1052, 1053, 1056, 1058, 1062, 1074, 1076,
#         1081, 1089, 1092, 1094, 1095, 1100, 1102, 1108, 1110, 1112, 1114,
#         1115, 1118, 1124, 1126, 1127, 1131, 1136, 1139, 1140, 1148, 1150,
#         1151, 1159, 1162, 1164, 1167, 1169, 1171, 1172, 1173, 1174, 1175,
#         1182, 1188, 1189, 1198, 1199, 1200, 1207, 1210, 1211, 1212, 1214,
#         1220, 1223, 1225, 1226, 1230, 1231, 1234, 1244, 1246, 1249, 1253,
#         1263, 1264, 1265, 1267, 1273, 1276, 1278, 1282, 1283, 1286, 1287,
#         1289, 1294, 1299, 1300, 1303, 1307, 1311, 1313, 1322, 1323, 1326,
#         1328, 1332, 1335, 1343, 1352, 1360, 1363, 1367, 1368, 1369, 1371,
#         1372, 1376, 1378, 1379, 1386, 1391, 1396, 1397, 1399, 1409, 1410,
#         1411, 1419, 1421, 1432, 1433, 1435, 1436, 1441, 1445, 1449, 1451,
#         1454, 1455, 1457, 1464, 1465, 1469, 1471, 1473, 1480, 1482, 1483,
#         1485, 1487, 1489, 1494, 1498, 1505, 1506, 1510, 1514, 1515, 1518,
#         1522, 1530, 1533, 1534, 1535, 1537, 1539, 1541, 1543, 1553, 1556,
#         1558, 1559, 1568, 1572, 1573, 1575, 1586, 1592, 1594, 1596, 1597,
#         1605, 1606, 1607, 1617, 1618, 1620, 1624, 1626, 1627, 1631, 1638,
#         1646, 1647, 1648, 1652, 1659, 1677, 1678, 1681, 1687, 1688, 1693,
#         1700, 1710, 1716, 1718, 1719, 1732, 1735, 1738, 1742, 1744, 1747,
#         1751, 1758, 1762, 1765, 1768, 1769, 1774, 1775, 1777, 1784, 1789,
#         1790, 1795, 1796, 1797, 1798, 1805, 1806, 1807, 1809, 1810, 1811,
#         1814, 1816, 1818, 1820, 1821, 1822, 1825, 1831, 1832, 1834, 1838,
#         1841, 1844, 1846, 1852, 1855, 1859, 1875, 1876, 1878, 1882, 1885,
#         1893, 1898, 1902, 1907, 1908, 1912, 1914, 1918, 1920, 1921, 1922,
#         1930, 1932, 1933, 1935, 1943, 1944, 1946, 1948, 1949, 1952, 1953,
#         1954, 1956, 1961, 1962, 1965, 1969, 1971, 1973, 1984, 1987, 1989,
#         1992, 1994, 1995, 1999]),)

# %%
np.where((a == 842) | (a == 563))
# Out:
# (array([   0,    2, 1175, 1825]),)

# %%
np.asarray((a == 842) | (a == 563)).nonzero()
# Out:
# (array([   0,    2, 1175, 1825]),)

# %%
np.arange(a.shape[0])
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999])

# %%
import scipy.stats as st

# %%
blue = df['blue'].values

# %%
st.mode(blue)
# Out:
# ModeResult(mode=array([0]), count=array([1010]))
